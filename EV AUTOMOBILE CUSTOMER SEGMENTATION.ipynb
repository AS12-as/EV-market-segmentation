# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the CSV File
EV= pd.read_csv("train-set.csv")

# %%
EV
# Out:
#       CustomerID  Gender Married  Age Graduated     Profession
# 0         462809    Male      No   22        No     Healthcare  \
# 1         462643  Female     Yes   38       Yes       Engineer
# 2         466315  Female     Yes   67       Yes       Engineer
# 3         461735    Male     Yes   67       Yes         Lawyer
# 4         462669  Female     Yes   40       Yes  Entertainment
# ...          ...     ...     ...  ...       ...            ...
# 8063      464018    Male      No   22        No            NaN
# 8064      464685    Male      No   35        No      Executive
# 8065      465406  Female      No   33       Yes     Healthcare
# 8066      467299  Female      No   27       Yes     Healthcare
# 8067      461879    Male     Yes   37       Yes      Executive
#
#       WorkExperience SpendingScore  FamilySize
# 0                1.0           Low         4.0
# 1                NaN       Average         3.0
# 2                1.0           Low         1.0
# ...

# %%
EV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      8068 non-null   int64
#  1   Gender          8068 non-null   object
#  2   Married         7928 non-null   object
#  3   Age             8068 non-null   int64
#  4   Graduated       7990 non-null   object
#  5   Profession      7944 non-null   object
#  6   WorkExperience  7239 non-null   float64
#  7   SpendingScore   8068 non-null   object
#  8   FamilySize      7733 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 567.4+ KB

# %%
EV.shape
# Out:
# (8068, 9)

# %%
EV.size
# Out:
# 72612

# %%
EV.describe()
# Out:
#           CustomerID          Age  WorkExperience   FamilySize
# count    8068.000000  8068.000000     7239.000000  7733.000000
# mean   463479.214551    43.466906        2.641663     2.850123
# std      2595.381232    16.711696        3.406763     1.531413
# min    458982.000000    18.000000        0.000000     1.000000
# 25%    461240.750000    30.000000        0.000000     2.000000
# 50%    463472.500000    40.000000        1.000000     3.000000
# 75%    465744.250000    53.000000        4.000000     4.000000
# max    467974.000000    89.000000       14.000000     9.000000

# %%
EV.isnull()
# Out:
#       CustomerID  Gender  Married    Age  Graduated  Profession
# 0          False   False    False  False      False       False  \
# 1          False   False    False  False      False       False
# 2          False   False    False  False      False       False
# 3          False   False    False  False      False       False
# 4          False   False    False  False      False       False
# ...          ...     ...      ...    ...        ...         ...
# 8063       False   False    False  False      False        True
# 8064       False   False    False  False      False       False
# 8065       False   False    False  False      False       False
# 8066       False   False    False  False      False       False
# 8067       False   False    False  False      False       False
#
#       WorkExperience  SpendingScore  FamilySize
# 0              False          False       False
# 1               True          False       False
# 2              False          False       False
# ...

# %%
EV.isnull().sum()
# Out:
# CustomerID          0
# Gender              0
# Married           140
# Age                 0
# Graduated          78
# Profession        124
# WorkExperience    829
# SpendingScore       0
# FamilySize        335
# dtype: int64

# %%
EV["WorkExperience"].fillna(1, inplace= True) #filling the work experience with the max value in the dataset

# %%
EV
# Out:
#       CustomerID  Gender Married  Age Graduated     Profession
# 0         462809    Male      No   22        No     Healthcare  \
# 1         462643  Female     Yes   38       Yes       Engineer
# 2         466315  Female     Yes   67       Yes       Engineer
# 3         461735    Male     Yes   67       Yes         Lawyer
# 4         462669  Female     Yes   40       Yes  Entertainment
# ...          ...     ...     ...  ...       ...            ...
# 8063      464018    Male      No   22        No            NaN
# 8064      464685    Male      No   35        No      Executive
# 8065      465406  Female      No   33       Yes     Healthcare
# 8066      467299  Female      No   27       Yes     Healthcare
# 8067      461879    Male     Yes   37       Yes      Executive
#
#       WorkExperience SpendingScore  FamilySize
# 0                1.0           Low         4.0
# 1                1.0       Average         3.0
# 2                1.0           Low         1.0
# ...

# %%
EV
# Out:
#       CustomerID  Gender Married  Age Graduated     Profession
# 0         462809    Male      No   22        No     Healthcare  \
# 1         462643  Female     Yes   38       Yes       Engineer
# 2         466315  Female     Yes   67       Yes       Engineer
# 3         461735    Male     Yes   67       Yes         Lawyer
# 4         462669  Female     Yes   40       Yes  Entertainment
# ...          ...     ...     ...  ...       ...            ...
# 8063      464018    Male      No   22        No            NaN
# 8064      464685    Male      No   35        No      Executive
# 8065      465406  Female      No   33       Yes     Healthcare
# 8066      467299  Female      No   27       Yes     Healthcare
# 8067      461879    Male     Yes   37       Yes      Executive
#
#       WorkExperience SpendingScore  FamilySize
# 0                1.0           Low         4.0
# 1                1.0       Average         3.0
# 2                1.0           Low         1.0
# ...

# %%
EV.isnull().sum()
# Out:
# CustomerID          0
# Gender              0
# Married           140
# Age                 0
# Graduated          78
# Profession        124
# WorkExperience      0
# SpendingScore       0
# FamilySize        335
# dtype: int64

# %%
EV_new= EV.dropna() #dropout all other na values as they are very less in numbers as compared to actual dataset

# %%
EV_new
# Out:
#       CustomerID  Gender Married  Age Graduated     Profession
# 0         462809    Male      No   22        No     Healthcare  \
# 1         462643  Female     Yes   38       Yes       Engineer
# 2         466315  Female     Yes   67       Yes       Engineer
# 3         461735    Male     Yes   67       Yes         Lawyer
# 4         462669  Female     Yes   40       Yes  Entertainment
# ...          ...     ...     ...  ...       ...            ...
# 8062      463002    Male     Yes   41       Yes         Artist
# 8064      464685    Male      No   35        No      Executive
# 8065      465406  Female      No   33       Yes     Healthcare
# 8066      467299  Female      No   27       Yes     Healthcare
# 8067      461879    Male     Yes   37       Yes      Executive
#
#       WorkExperience SpendingScore  FamilySize
# 0                1.0           Low         4.0
# 1                1.0       Average         3.0
# 2                1.0           Low         1.0
# ...

# %%
EV_var=EV_new.drop('CustomerID', axis=1)
EV_var
# Out:
#       Gender Married  Age Graduated     Profession  WorkExperience
# 0       Male      No   22        No     Healthcare             1.0  \
# 1     Female     Yes   38       Yes       Engineer             1.0
# 2     Female     Yes   67       Yes       Engineer             1.0
# 3       Male     Yes   67       Yes         Lawyer             0.0
# 4     Female     Yes   40       Yes  Entertainment             1.0
# ...      ...     ...  ...       ...            ...             ...
# 8062    Male     Yes   41       Yes         Artist             0.0
# 8064    Male      No   35        No      Executive             3.0
# 8065  Female      No   33       Yes     Healthcare             1.0
# 8066  Female      No   27       Yes     Healthcare             1.0
# 8067    Male     Yes   37       Yes      Executive             0.0
#
#      SpendingScore  FamilySize
# 0              Low         4.0
# 1          Average         3.0
# 2              Low         1.0
# 3             High         2.0
# ...

# %%
EV_var
# Out:
#       Gender Married  Age Graduated     Profession  WorkExperience
# 0       Male      No   22        No     Healthcare             1.0  \
# 1     Female     Yes   38       Yes       Engineer             1.0
# 2     Female     Yes   67       Yes       Engineer             1.0
# 3       Male     Yes   67       Yes         Lawyer             0.0
# 4     Female     Yes   40       Yes  Entertainment             1.0
# ...      ...     ...  ...       ...            ...             ...
# 8062    Male     Yes   41       Yes         Artist             0.0
# 8064    Male      No   35        No      Executive             3.0
# 8065  Female      No   33       Yes     Healthcare             1.0
# 8066  Female      No   27       Yes     Healthcare             1.0
# 8067    Male     Yes   37       Yes      Executive             0.0
#
#      SpendingScore  FamilySize
# 0              Low         4.0
# 1          Average         3.0
# 2              Low         1.0
# 3             High         2.0
# ...

# %%
#Visualize the data

# %%
sns.countplot(x="Gender", data= EV_var)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Gender", data= EV_var, hue="Graduated")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.barplot(x="Gender", y="WorkExperience", data=EV_var)
plt.show()

# %%
sns.countplot(x="Gender", data= EV_var, hue="FamilySize")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Gender", data= EV_var, hue="SpendingScore")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Gender", data= EV_var, hue="Married")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.displot(data=EV_var, x="Age")

# %%
sns.displot(data=EV_var, x="SpendingScore")

# %%
sns.boxplot(data=EV_var, x="Age", y="SpendingScore")
# Out:
# <Axes: xlabel='Age', ylabel='SpendingScore'>

# %%
EV_var
# Out:
#       Gender Married  Age Graduated     Profession  WorkExperience
# 0       Male      No   22        No     Healthcare             1.0  \
# 1     Female     Yes   38       Yes       Engineer             1.0
# 2     Female     Yes   67       Yes       Engineer             1.0
# 3       Male     Yes   67       Yes         Lawyer             0.0
# 4     Female     Yes   40       Yes  Entertainment             1.0
# ...      ...     ...  ...       ...            ...             ...
# 8062    Male     Yes   41       Yes         Artist             0.0
# 8064    Male      No   35        No      Executive             3.0
# 8065  Female      No   33       Yes     Healthcare             1.0
# 8066  Female      No   27       Yes     Healthcare             1.0
# 8067    Male     Yes   37       Yes      Executive             0.0
#
#      SpendingScore  FamilySize
# 0              Low         4.0
# 1          Average         3.0
# 2              Low         1.0
# 3             High         2.0
# ...

# %%
# Prepare Data for Clustering and segmentation
EV_var['Profession'].unique()
# Out:
# array(['Healthcare', 'Engineer', 'Lawyer', 'Entertainment', 'Artist',
#        'Doctor', 'Homemaker', 'Marketing', 'Executive'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
dfle= EV_var
dfle.Gender= le.fit_transform(dfle.Gender)
dfle
# Out:
#       Gender Married  Age Graduated     Profession  WorkExperience
# 0          1      No   22        No     Healthcare             1.0  \
# 1          0     Yes   38       Yes       Engineer             1.0
# 2          0     Yes   67       Yes       Engineer             1.0
# 3          1     Yes   67       Yes         Lawyer             0.0
# 4          0     Yes   40       Yes  Entertainment             1.0
# ...      ...     ...  ...       ...            ...             ...
# 8062       1     Yes   41       Yes         Artist             0.0
# 8064       1      No   35        No      Executive             3.0
# 8065       0      No   33       Yes     Healthcare             1.0
# 8066       0      No   27       Yes     Healthcare             1.0
# 8067       1     Yes   37       Yes      Executive             0.0
#
#      SpendingScore  FamilySize
# 0              Low         4.0
# 1          Average         3.0
# 2              Low         1.0
# 3             High         2.0
# ...

# %%
dfle1= dfle
dfle1.Married= le.fit_transform(dfle1.Married)
dfle1
# Out:
#       Gender  Married  Age Graduated     Profession  WorkExperience
# 0          1        0   22        No     Healthcare             1.0  \
# 1          0        1   38       Yes       Engineer             1.0
# 2          0        1   67       Yes       Engineer             1.0
# 3          1        1   67       Yes         Lawyer             0.0
# 4          0        1   40       Yes  Entertainment             1.0
# ...      ...      ...  ...       ...            ...             ...
# 8062       1        1   41       Yes         Artist             0.0
# 8064       1        0   35        No      Executive             3.0
# 8065       0        0   33       Yes     Healthcare             1.0
# 8066       0        0   27       Yes     Healthcare             1.0
# 8067       1        1   37       Yes      Executive             0.0
#
#      SpendingScore  FamilySize
# 0              Low         4.0
# 1          Average         3.0
# 2              Low         1.0
# ...

# %%
dfle2= dfle1
dfle2.Profession= le.fit_transform(dfle2.Profession)
dfle2
# Out:
#       Gender  Married  Age Graduated  Profession  WorkExperience
# 0          1        0   22        No           5             1.0  \
# 1          0        1   38       Yes           2             1.0
# 2          0        1   67       Yes           2             1.0
# 3          1        1   67       Yes           7             0.0
# 4          0        1   40       Yes           3             1.0
# ...      ...      ...  ...       ...         ...             ...
# 8062       1        1   41       Yes           0             0.0
# 8064       1        0   35        No           4             3.0
# 8065       0        0   33       Yes           5             1.0
# 8066       0        0   27       Yes           5             1.0
# 8067       1        1   37       Yes           4             0.0
#
#      SpendingScore  FamilySize
# 0              Low         4.0
# 1          Average         3.0
# 2              Low         1.0
# 3             High         2.0
# ...

# %%
dfle3= dfle2
dfle3.SpendingScore= le.fit_transform(dfle3.SpendingScore)
dfle3
# Out:
#       Gender  Married  Age Graduated  Profession  WorkExperience
# 0          1        0   22        No           5             1.0  \
# 1          0        1   38       Yes           2             1.0
# 2          0        1   67       Yes           2             1.0
# 3          1        1   67       Yes           7             0.0
# 4          0        1   40       Yes           3             1.0
# ...      ...      ...  ...       ...         ...             ...
# 8062       1        1   41       Yes           0             0.0
# 8064       1        0   35        No           4             3.0
# 8065       0        0   33       Yes           5             1.0
# 8066       0        0   27       Yes           5             1.0
# 8067       1        1   37       Yes           4             0.0
#
#       SpendingScore  FamilySize
# 0                 2         4.0
# 1                 0         3.0
# 2                 2         1.0
# 3                 1         2.0
# ...

# %%
dfle4= dfle3
dfle4.Graduated= le.fit_transform(dfle3.Graduated)
dfle4
# Out:
#       Gender  Married  Age  Graduated  Profession  WorkExperience
# 0          1        0   22          0           5             1.0  \
# 1          0        1   38          1           2             1.0
# 2          0        1   67          1           2             1.0
# 3          1        1   67          1           7             0.0
# 4          0        1   40          1           3             1.0
# ...      ...      ...  ...        ...         ...             ...
# 8062       1        1   41          1           0             0.0
# 8064       1        0   35          0           4             3.0
# 8065       0        0   33          1           5             1.0
# 8066       0        0   27          1           5             1.0
# 8067       1        1   37          1           4             0.0
#
#       SpendingScore  FamilySize
# 0                 2         4.0
# 1                 0         3.0
# 2                 2         1.0
# 3                 1         2.0
# ...

# %%
dfle4
# Out:
#       Gender  Married  Age  Graduated  Profession  WorkExperience
# 0          1        0   22          0           5             1.0  \
# 1          0        1   38          1           2             1.0
# 2          0        1   67          1           2             1.0
# 3          1        1   67          1           7             0.0
# 4          0        1   40          1           3             1.0
# ...      ...      ...  ...        ...         ...             ...
# 8062       1        1   41          1           0             0.0
# 8064       1        0   35          0           4             3.0
# 8065       0        0   33          1           5             1.0
# 8066       0        0   27          1           5             1.0
# 8067       1        1   37          1           4             0.0
#
#       SpendingScore  FamilySize
# 0                 2         4.0
# 1                 0         3.0
# 2                 2         1.0
# 3                 1         2.0
# ...

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=0, n_init="auto").fit(dfle4)

# %%
kmeans.labels_
# Out:
# array([0, 2, 1, ..., 0, 0, 0])

# %%
kmeans.predict
# Out:
# <bound method _BaseKMeans.predict of KMeans(n_clusters=3, n_init='auto', random_state=0)>

# %%
 kmeans.cluster_centers_
# Out:
# array([[ 0.54178767,  0.27718619, 28.60019361,  0.46498871,  3.25104873,
#          2.95256534,  1.68441433,  3.24975799],
#        [ 0.59289415,  0.94300518, 71.11843079,  0.66765359,  3.97631384,
#          1.28497409,  1.17838638,  2.22797927],
#        [ 0.54524129,  0.7613941 , 46.53887399,  0.78384718,  1.65482574,
#          2.51206434,  1.0713807 ,  2.70978552]])
